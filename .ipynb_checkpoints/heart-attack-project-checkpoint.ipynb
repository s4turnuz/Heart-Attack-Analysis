# %% [markdown]
# ### Import libs:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Get Data

# %%
# A dataset for heart attack classification 
heart_df = pd.read_csv('heart.csv')

# dateset to help charts
clone_heart_df = pd.read_csv('heart.csv')
display(heart_df)
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %% [markdown]
# ### About this dataset
# ###### Reff link: *https://www.kaggle.com/datasets/rashikrahmanpritom/heart-attack-analysis-prediction-dataset*

# %% [markdown]
# **Age** : Age of the patient
#
# **Sex** : Sex of the patient
#
# **exang** : Exercise induced angina (**1** = yes; **0** = no)
#
# **ca** : Number of major vessels (0-3)
#
# **cp** : Chest Pain type chest pain type
# Value **1**: typical angina
# Value **2**: atypical angina
# Value **3**: non-anginal pain
# Value **4**: asymptomatic
#
# **trtbps** : Resting blood pressure (in mm Hg)
#
# **chol** : Cholestoral in mg/dl fetched via BMI sensor
#
# **fbs** : (Fasting blood sugar > 120 mg/dl) (**1** = true; **0** = false)
#
# **rest_ecg** : Resting electrocardiographic results
# Value **0**: normal
# Value **1**: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
# Value **2**: showing probable or definite left ventricular hypertrophy by Estes' criteria
#
# **thalach** : Maximum heart rate achieved
#
# **target** :
# **0** = less chance of heart attack
# **1** = More chance of heart attack

# %% [markdown]
# ### Data processing (Data cleaning)

# %%
# some null value?
heart_df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
# some NaN value?
heart_df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %% [markdown]
# ### Rename cloned dataset for charts

# %%
clone_heart_df.loc[clone_heart_df['sex'] == 0, 'sex'] = 'F'
clone_heart_df.loc[clone_heart_df['sex'] == 1, 'sex'] = 'M'

clone_heart_df.loc[clone_heart_df['exng'] == 1, 'exng'] = 'Yes'
clone_heart_df.loc[clone_heart_df['exng'] == 0, 'exng'] = 'No'

clone_heart_df.loc[clone_heart_df['fbs'] == 1, 'fbs'] = 'True'
clone_heart_df.loc[clone_heart_df['fbs'] == 0, 'fbs'] = 'False'

clone_heart_df.loc[clone_heart_df['cp'] == 0, 'cp'] = 'Typical angina'
clone_heart_df.loc[clone_heart_df['cp'] == 1, 'cp'] = 'Atypical angina'
clone_heart_df.loc[clone_heart_df['cp'] == 2, 'cp'] = 'Non-anginal pain'
clone_heart_df.loc[clone_heart_df['cp'] == 3, 'cp'] = 'Asymptomatic'

clone_heart_df.loc[clone_heart_df['restecg'] == 0, 'restecg'] = 'Normal'
clone_heart_df.loc[clone_heart_df['restecg'] == 1, 'restecg'] = 'ST-T wave abnormality'
clone_heart_df.loc[clone_heart_df['restecg'] == 2, 'restecg'] = 'Left ventricular hypertrophy'

clone_heart_df.loc[clone_heart_df['output'] == 0, 'output'] = 'Less chance'
clone_heart_df.loc[clone_heart_df['output'] == 1, 'output'] = 'More chance'


display(clone_heart_df)
# Out:
#      age sex                cp  trtbps  chol    fbs                restecg  \
# 0     63   M      Asymptomatic     145   233   True                 Normal
# 1     37   M  Non-anginal pain     130   250  False  ST-T wave abnormality
# 2     41   F   Atypical angina     130   204  False                 Normal
# 3     56   M   Atypical angina     120   236  False  ST-T wave abnormality
# 4     57   F    Typical angina     120   354  False  ST-T wave abnormality
# ..   ...  ..               ...     ...   ...    ...                    ...
# 298   57   F    Typical angina     140   241  False  ST-T wave abnormality
# 299   45   M      Asymptomatic     110   264  False  ST-T wave abnormality
# 300   68   M    Typical angina     144   193   True  ST-T wave abnormality
# 301   57   M    Typical angina     130   131  False  ST-T wave abnormality
# 302   57   F   Atypical angina     130   236  False                 Normal
#
#      thalachh exng  oldpeak  slp  caa  thall       output
# ...

# %% [markdown]
# ### Some charts for analysis

# %%
# Pacient by gender

sns.set_theme(style="whitegrid")
ax = sns.countplot(x ='sex', hue='output', data = clone_heart_df, palette='magma', dodge=True)

ax.set_title('Number of heart attack per patient')
ax.set_xlabel('Gender')
ax.set_ylabel('Quantity')
ax.figure.set_size_inches(5,6)

plt.legend(title='Probability')

for container in ax.containers:
    ax.bar_label(container)

# %%
sns.set_theme(style="whitegrid")

g = sns.countplot(
                 x = "cp",
                 data = clone_heart_df, 
                 hue = "output",
                 palette = "Set2",
                 dodge=True)

g.set_title('Number of heart attack per chest pain')
g.set_xlabel('Chest pain type')
g.set_ylabel('Quantity')

plt.legend(title='Probability')

g.figure.set_size_inches(15,6)

for container in g.containers:
    g.bar_label(container)

# %%
sns.set_theme(style="whitegrid")

g = sns.countplot(
                 x = "restecg",
                 data = clone_heart_df, 
                 hue = "cp",
                 palette="mako",
                 dodge=True)

g.set_title('Number of electrocardiographic results per Chest pain')
g.set_xlabel('Quantity')
# g.set_xlabel('Resting electrocardiographic results')
# g.set_ylabel('Quantity')
g.set_ylabel('')

plt.legend(title='Chest pain')

g.figure.set_size_inches(14,7)

for container in g.containers:
    g.bar_label(container)

# %%
a = sns.set(style = 'darkgrid') 
a = sns.stripplot(x="chol", y="restecg", hue="output", data=clone_heart_df, palette="Set2", dodge=True)
a.set_title('Electrocardiographic results by Cholestoral level')
a.set_xlabel('Cholestoral in mg/dl')
a.set_ylabel('Chest pain')
plt.legend(title='Chest pain')
a.figure.set_size_inches(15,5)

# %%
b = sns.set(style = 'darkgrid') 
b = sns.stripplot(x="thalachh", y="restecg", hue="output", data=clone_heart_df, palette="tab10", dodge=True)
b.figure.set_size_inches(15,5)

# %%
plt.figure(1)
plt.figure(figsize=(40,40))

sns.set_theme(style="whitegrid")
plt.subplot(2,2,1)
b = sns.boxenplot(data=clone_heart_df, x="caa", y="thalachh",hue="restecg", palette="hls")
plt.subplot(2,2,2)
a = sns.boxenplot(data=clone_heart_df, x="caa", y="trtbps", hue="restecg", palette="Set2")


a.set_title('Electrocardiographic per Blood pressure')
a.set_xlabel('Number of major vessels')
a.set_ylabel('Blood pressure (in mm Hg)')

# plt.legend(title='Electrocardiographic results')
sns.move_legend(a, "upper right", title='Electrocardiographic results')
# a.move_legend(title='Electrocardiographic results')

a.figure.set_size_inches(20, 20)

b.set_title('Electrocardiographic per maximum heart rate')
b.set_xlabel('Number of major vessels')
b.set_ylabel('Maximum heart rate')

# plt.legend(title='Electrocardiographic results')
sns.move_legend(b, "upper right", title='Electrocardiographic results')
# b.move_legend(title='Electrocardiographic results')

b.figure.set_size_inches(20, 20)
